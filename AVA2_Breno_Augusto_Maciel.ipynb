# %% [markdown]
# ## **Conectando ao drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importação das bibliotecas que iremos utilizar**

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
import seaborn as sbs
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Questão 1 - Checagem do arquivo**

# %%
df = pd.read_csv('/content/drive/MyDrive/Classroom/ANALISE DE DADOS TURMA 28 - SA/igm_modificado.csv')
df.head(5)
# Out:
#          regiao estado              municipio  codigo_mun  capital  \
# 0       SUDESTE     SP               ILHABELA     3520400        0
# 1       SUDESTE     SP    SANTANA DE PARNAIBA     3547304        0
# 2           SUL     SC              BOMBINHAS     4202453        0
# 3       SUDESTE     SP  SAO BERNARDO DO CAMPO     3548708        0
# 4  CENTRO-OESTE     DF               BRASILIA     5300108        1
#
#              porte  populacao      area densidade_dem           pib  \
# 0  Pequeno porte 2     32,782    347.52          81.1  3.256712e+06
# 1     Grande porte    129,261    179.95         604.7  7.373603e+06
# 2  Pequeno porte 1     18,052     35.92           398  3.773573e+05
# 3     Grande porte    822,242    409.53      1,869.40  4.766853e+07
# 4     Grande porte  2,977,216  5,780.00         444.7  1.753628e+08
#
#       pib_pc  participacao_transf_receita  servidores  comissionados  \
# 0  105112.86                         77.0      1495.0           74.0
# ...

# %%
df.tail(5)
# Out:
#      regiao estado                municipio  codigo_mun  capital  \
# 5565  NORTE     TO             RIO DOS BOIS     1718709        0
# 5566  NORTE     TO       AXIXA DO TOCANTINS     1702901        0
# 5567  NORTE     TO               FILADELFIA     1707702        0
# 5568  NORTE     TO  PONTE ALTA DO TOCANTINS     1717909        0
# 5569  NORTE     TO             SILVANOPOLIS     1720655        0
#
#                 porte populacao      area densidade_dem       pib    pib_pc  \
# 5565  Pequeno porte 1     2,787    845.07             3  27136.71   9995.11
# 5566  Pequeno porte 1     9,741    150.21          61.8  80205.45   8326.98
# 5567  Pequeno porte 1     8,871  1,988.08           4.3  78500.72   8920.54
# 5568  Pequeno porte 1     7,872  6,491.13           1.1  59147.57   7754.01
# 5569  Pequeno porte 1     5,372  1,258.83             4  77734.86  14697.46
#
#       participacao_transf_receita  servidores  comissionados  \
# ...

# %%
df.sample(5)
# Out:
#         regiao estado             municipio  codigo_mun  capital  \
# 3355   SUDESTE     MG            DIAMANTINA     3121605        0
# 4144   SUDESTE     MG             RIACHINHO     3154457        0
# 1092     NORTE     TO  PARAISO DO TOCANTINS     1716109        0
# 2144  NORDESTE     RN       LAGOA DE PEDRAS     2406304        0
# 4005  NORDESTE     PE              BREJINHO     2602506        0
#
#                 porte populacao      area densidade_dem        pib    pib_pc  \
# 3355  Pequeno porte 2    48,095  3,891.66          11.8  563263.52  11821.59
# 4144  Pequeno porte 1     8,283  1,719.27           4.7   81348.65   9852.08
# 1092  Pequeno porte 2    49,727  1,268.06            35  820058.00  17183.35
# 2144  Pequeno porte 1     7,529    117.97          59.4   44593.59   6049.05
# 4005  Pequeno porte 1     7,464    106.28          68.8   41320.14   5535.92
#
#       participacao_transf_receita  servidores  comissionados  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   regiao                       5570 non-null   object
#  1   estado                       5570 non-null   object
#  2   municipio                    5570 non-null   object
#  3   codigo_mun                   5570 non-null   int64
#  4   capital                      5570 non-null   int64
#  5   porte                        5570 non-null   object
#  6   populacao                    5570 non-null   object
#  7   area                         5570 non-null   object
#  8   densidade_dem                5566 non-null   object
#  9   pib                          5570 non-null   float64
#  10  pib_pc                       5570 non-null   float64
#  11  participacao_transf_receita  4893 non-null   float64
#  12  servidores                   5233 non-null   float64
# ...

# %%
df.shape
# Out:
# (5570, 32)

# %%
df.describe()
# Out:
#          codigo_mun      capital           pib         pib_pc  \
# count  5.570000e+03  5570.000000  5.570000e+03    5570.000000
# mean   3.253591e+06     0.004847  9.544801e+05   17374.483108
# std    9.849103e+05     0.069461  9.502661e+06   20133.341193
# min    1.100015e+06     0.000000  9.678440e+03    3241.290000
# 25%    2.512126e+06     0.000000  5.922529e+04    7077.357500
# 50%    3.146280e+06     0.000000  1.301531e+05   12621.810000
# 75%    4.119190e+06     0.000000  3.426808e+05   21262.387500
# max    5.300108e+06     1.000000  5.707062e+08  715193.700000
#
#        participacao_transf_receita     servidores  comissionados  \
# count                  4893.000000    5233.000000    5570.000000
# mean                     82.316575     771.324861      96.371275
# std                      11.272136    3209.755931     234.994469
# min                       0.000000       1.000000       0.000000
# 25%                      77.000000     190.000000      24.000000
# ...

# %% [markdown]
# ## **Questão 2 - Escolhendo as duas variáveis numéricas**

# %% [markdown]
# Letra A

# %%
df_reduzido = df[['gasto_pc_educacao',
                  'nota_ciencias']]

# %%
df_reduzido.describe()
# Out:
#        gasto_pc_educacao  nota_ciencias
# count        4880.000000    5558.000000
# mean          769.775533     460.124417
# std           277.841845      19.275298
# min            56.600000     385.000000
# 25%           585.892500     446.324306
# 50%           731.825000     457.549922
# 75%           898.625000     471.752760
# max          3695.930000     550.566667

# %%
print('Este era o shape original:', df.shape)
# Out:
# Este era o shape original: (5570, 32)

# %%
print('E este é o que usarei para a análise das duas variáveis selecionadas:', df_reduzido.shape)
# Out:
# E este é o que usarei para a análise das duas variáveis selecionadas: (5570, 2)

# %%
df_reduzido['gasto_pc_educacao'].mean()
# Out:
# 769.7755327868852

# %%
df_reduzido['nota_ciencias'].mean()
# Out:
# 460.12441735582166

# %%
df_reduzido['gasto_pc_educacao'].median()
# Out:
# 731.825

# %%
df_reduzido['nota_ciencias'].median()
# Out:
# 457.54992248062007

# %%
df_reduzido['gasto_pc_educacao'].mode()
# Out:
# 0    677.14
# 1    681.35
# 2    716.34
# 3    753.82
# Name: gasto_pc_educacao, dtype: float64

# %%
df_reduzido['nota_ciencias'].mode()
# Out:
# 0     433.600000
# 1     438.918182
# 2     441.766667
# 3     444.104348
# 4     444.214286
# 5     444.600000
# 6     449.775000
# 7     451.980000
# 8     462.000000
# 9     473.361905
# 10    474.833333
# 11    476.900000
# 12    480.400000
# Name: nota_ciencias, dtype: float64

# %% [markdown]
# **Em ambos os casos, a média é maior que a mediana. Isso implica que a cauda se estende para o lado direito, no mostrando uma assimetria positiva.**

# %% [markdown]
# Questão B

# %%
df_reduzido['gasto_pc_educacao'].quantile(0.25)
# Out:
# 585.8925

# %%
df_reduzido['gasto_pc_educacao'].quantile(0.75)
# Out:
# 898.625

# %%
df_reduzido['nota_ciencias'].quantile(0.25)
# Out:
# 446.3243059159317

# %%
df_reduzido['nota_ciencias'].quantile(0.75)
# Out:
# 471.75275983558436

# %% [markdown]
# Letra C

# %%
sbs.set(style='whitegrid')

# %%
sbs.boxplot(x=df_reduzido['gasto_pc_educacao'])
# Out:
# <Axes: xlabel='gasto_pc_educacao'>

# %%
sbs.boxplot(x=df_reduzido['nota_ciencias'])
# Out:
# <Axes: xlabel='nota_ciencias'>

# %% [markdown]
# Letra D

# %%
df_reduzido['gasto_pc_educacao'].std()
# Out:
# 277.8418453534947

# %%
df_reduzido['nota_ciencias'].std()
# Out:
# 19.275297760328815

# %%
df_reduzido['gasto_pc_educacao'].var()
# Out:
# 77196.09102943528

# %%
df_reduzido['nota_ciencias'].var()
# Out:
# 371.537103749337

# %% [markdown]
# ## **Questão 3**

# %%
df_reduzido2 = df[['anos_estudo_empreendedor',
                   'taxa_empreendedorismo']]

# %%
df_reduzido2.describe()
# Out:
#        anos_estudo_empreendedor  taxa_empreendedorismo
# count               5570.000000            5570.000000
# mean                   6.124378               0.250939
# std                    1.462946               0.098014
# min                    0.000000               0.000000
# 25%                    5.039926               0.190000
# 50%                    6.049990               0.230000
# 75%                    7.175247               0.290000
# max                   11.553164               0.770000

# %%
df_reduzido2.corr()
# Out:
#                           anos_estudo_empreendedor  taxa_empreendedorismo
# anos_estudo_empreendedor                  1.000000              -0.222317
# taxa_empreendedorismo                    -0.222317               1.000000

# %% [markdown]
# **Isso nos mostra que quanto maior for o tempo estudando para ser um empreendedor, menor será a taxa de empreendedorismo nos Estados Brasileiros.**

# %% [markdown]
# ## **Questão 4**

# %%
sbs.scatterplot(x='anos_estudo_empreendedor', y='taxa_empreendedorismo', data=df_reduzido2)
plt.xlabel('anos_estudo_empreendedor')
plt.ylabel('taxa_empreendedorismo')
plt.show()
